# %%
# Question 1

from typing import List

class Solution:
    def maxProduct(self, nums: List[int]) -> int:
        max_ = -999
        max2 = -999
        for i in range(len(nums)) :
            if nums[i] >= max_:
                max2 = max_
                max_ = nums[i]
            elif nums[i] > max2 and nums[i]!= max_:
                max2 = nums[i]
        return (max_-1) * (max2-1)

# %%
q1 = Solution()
q1.maxProduct([19,15,4,5])
# Out:
# 252

# %%
# Question 2

class Solution:
    def numTeams(self, rating: List[int]) -> int:
        n = len(rating)
        teams = 0
        for j in range(n):
            left_smaller = left_greater = 0
            right_smaller = right_greater = 0
            for i in range(j):
                if rating[i] < rating[j]:
                    left_smaller += 1
                elif rating[i] > rating[j]:
                    left_greater += 1

            for k in range(j + 1, n):
                if rating[k] < rating[j]:
                    right_smaller += 1
                elif rating[k] > rating[j]:
                    right_greater += 1
            teams += left_smaller * right_greater
            teams += left_greater * right_smaller
        return teams

# %%
q2 = Solution()
q2.numTeams([2,5,3,4,1])
# Out:
# 3

# %%
# Question 3

class Solution:
    def busyStudent(self, startTime: List[int], endTime: List[int], queryTime: int) -> int:
        cnt = 0
        for i, j in zip(startTime, endTime):
            if queryTime <= j and i <= queryTime:
                cnt += 1
        return cnt

# %%
q3 = Solution()
q3.busyStudent([1,2,3], [3,5,7], 4)
# Out:
# 2

# %%
# Question 4

class Solution:
    def numberOfSteps(self, num: int) -> int:
        cnt = 0
        while num > 0:
            if num % 2 == 0:
                num = num / 2
            else :
                num = num - 1
            cnt += 1
        return cnt

# %%
q4 = Solution()
q4.numberOfSteps(14)
# Out:
# 6

# %%
# Question 5

class Solution:
    def countBits(self, n: int) -> List[int]:
        ans = [0] * (n + 1)
        for i in range(1, n + 1):
            ans[i] = ans[i // 2] + (i % 2)
        return ans

# %%
q5 = Solution()
q5.countBits(9)
# Out:
# [0, 1, 1, 2, 1, 2, 2, 3, 1, 2]

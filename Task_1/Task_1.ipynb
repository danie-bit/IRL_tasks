# %%
from typing import List

class Solution:
    def runningSum(self, nums: List[int]) -> List[int]:
        sum_list = []
        curr_sum = 0
        for i in range(len(nums)):
            sum_list.append(nums[i] + curr_sum)
            curr_sum = sum_list[i]
        return sum_list

# %%
q1 = Solution()
q1.runningSum([1,2,3,4])
# Out:
# [1, 3, 6, 10]

# %%
class Solution:
    def shuffle(self, nums: List[int], n: int) -> List[int]:
        tracking_cnt = 0
        start_ind = 0
        new_list = []
        midd_ind = n
        while tracking_cnt <= 2 * n -1:
            new_list.append(nums[start_ind])
            start_ind += 1
            new_list.append(nums[midd_ind])
            midd_ind += 1
            tracking_cnt += 2
        return new_list

# %%
q2 = Solution()
q2.shuffle([2,5,1,3,4,7], 3)
# Out:
# [2, 3, 5, 4, 1, 7]

# %%
class Solution:
    def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:
        max_candies = max(candies)
        bool_list = []
        for i in range(len(candies)):
            if (candies[i] + extraCandies) >= max_candies :
                bool_list.append(True)
            else :
                bool_list.append(False)
        return bool_list

# %%
q3 = Solution()
q3.kidsWithCandies([2,3,5,1,3],3)
# Out:
# [True, True, True, False, True]
